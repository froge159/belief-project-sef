# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

# %%
model_id = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    dtype=torch.float16,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
directory = "/content/hf_cache/mistral-7b"
model.save_pretrained(directory)
tokenizer.save_pretrained(directory)
# Out:
# ('/content/drive/MyDrive/SEF/Models/mistral-7b/tokenizer_config.json',
#  '/content/drive/MyDrive/SEF/Models/mistral-7b/special_tokens_map.json',
#  '/content/drive/MyDrive/SEF/Models/mistral-7b/tokenizer.model',
#  '/content/drive/MyDrive/SEF/Models/mistral-7b/added_tokens.json',
#  '/content/drive/MyDrive/SEF/Models/mistral-7b/tokenizer.json')
